# %% [markdown]
# # **Heart Disease Classification**

# %% [markdown]
# ## Data Preparation

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import tensorflow as tf
from tensorflow import keras
from tensorflow import feature_column
from tensorflow.keras import layers
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv('https://storage.googleapis.com/applied-dl/heart.csv')
data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   1       145   233    1        2      150      0      2.3      3
# 1   67    1   4       160   286    0        2      108      1      1.5      2
# 2   67    1   4       120   229    0        2      129      1      2.6      2
# 3   37    1   3       130   250    0        0      187      0      3.5      3
# 4   41    0   2       130   204    0        2      172      0      1.4      1
#
#    ca        thal  target
# 0   0       fixed       0
# 1   3      normal       1
# 2   2  reversible       0
# 3   0      normal       0
# 4   0      normal       0

# %%
print('Shape of Data : ', data.shape)
# Out:
# Shape of Data :  (303, 14)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
# age         303 non-null int64
# sex         303 non-null int64
# cp          303 non-null int64
# trestbps    303 non-null int64
# chol        303 non-null int64
# fbs         303 non-null int64
# restecg     303 non-null int64
# thalach     303 non-null int64
# exang       303 non-null int64
# oldpeak     303 non-null float64
# slope       303 non-null int64
# ca          303 non-null int64
# thal        303 non-null object
# target      303 non-null int64
# dtypes: float64(1), int64(12), object(1)
# memory usage: 33.3+ KB

# %%
print("Number of target variable : ", data['target'].nunique())
# Out:
# Number of target variable :  2

# %% [markdown]
# Attribute Information:
#
# 1. **age**
# 2. **sex**
# 3. **cp** or chest pain type (4 values)
# 4. **trestbps** or resting blood pressure
# 5. **chol** or serum cholestoral in mg/dl
# 6. **fbs** or fasting blood sugar > 120 mg/dl
# 7. **restecg** or resting electrocardiographic results (values 0,1,2)
# 8. **thalach** or maximum heart rate achieved
# 9. **exang** or exercise induced angina
# 10. **oldpeak** = ST depression induced by exercise relative to rest
# 11. the **slope** of the peak exercise ST segment
# 12. **ca** or number of major vessels (0-3) colored by flourosopy
# 13. **thal**: 3 = normal; 6 = fixed defect; 7 = reversable defect

# %%
data.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.594059    0.676568    3.108911  131.785479  246.547855    0.148515
# std      9.016370    0.468560    1.028414   17.748338   52.175933    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     48.000000    0.000000    2.000000  120.000000  211.000000    0.000000
# 50%     56.000000    1.000000    3.000000  130.000000  241.000000    0.000000
# 75%     61.000000    1.000000    4.000000  140.000000  275.000000    0.000000
# max     77.000000    1.000000    4.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.990099  149.194719    0.326733    1.057756    1.590759    0.683168
# std      0.988293   23.173368    0.469794    1.165025    0.617767    0.937773
# min      0.000000   71.000000    0.000000    0.000000    1.000000    0.000000
# 25%      0.000000  132.000000    0.000000    0.000000    1.000000    0.000000
# 50%      1.000000  152.000000    0.000000    0.800000    2.000000    0.000000
# 75%      2.000000  165.500000    1.000000    1.600000    2.000000    1.000000
# max      2.000000  202.000000    1.000000    6.200000    3.000000    3.000000
#
#            target
# count  303.000000
# mean     0.273927
# std      0.446710
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      1.000000

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# **1. Warming up**

# %% [markdown]
# Frequency distribution of **target** variable
#
# (0 : Absence of heart disease, 1 : Presence of heart disease)

# %%
data['target'].value_counts()
# Out:
# 0    220
# 1     83
# Name: target, dtype: int64

# %%
sns.countplot(x = "target", data = data)
plt.show()

# %% [markdown]
# That looks like a pretty well-distributed dataset, considering the number of rows.

# %% [markdown]
# Frequency distribution of **sex** with respect to **target**

# %%
data.groupby('sex')['target'].value_counts()
# Out:
# sex  target
# 0    0          82
#      1          16
# 1    0         138
#      1          67
# Name: target, dtype: int64

# %%
sns.countplot(x = "sex", hue = "target", data = data)
plt.show()

# %% [markdown]
# **2. Estimating correlation coefficient**

# %%
correlation = data.corr()
correlation['target'].sort_values(ascending = False)
# Out:
# target      1.000000
# ca          0.476613
# oldpeak     0.475324
# cp          0.381725
# exang       0.361026
# slope       0.359572
# age         0.198701
# sex         0.171564
# trestbps    0.129389
# restecg     0.126169
# fbs         0.097252
# chol        0.083327
# thalach    -0.386459
# Name: target, dtype: float64

# %% [markdown]
# As we can see that the **cp** and **thalach** variables are mildly positively correlated with **target** variable.
#
# So, We will analyze the interaction between these features and **target** variable

# %% [markdown]
# Frequency distribution of **cp**
#
# **cp** stands for chest pain type (4 values)

# %%
data['cp'].value_counts()
# Out:
# 4    142
# 3     84
# 2     49
# 1     24
# 0      4
# Name: cp, dtype: int64

# %%
sns.countplot(x = "cp", data = data)
plt.show()

# %% [markdown]
# Analysis of **cp** and **target** variable

# %%
data.groupby('cp')['target'].value_counts()
# Out:
# cp  target
# 0   0          4
# 1   0         22
#     1          2
# 2   0         46
#     1          3
# 3   0         75
#     1          9
# 4   0         73
#     1         69
# Name: target, dtype: int64

# %%
sns.countplot(x = "cp", hue = "target", data = data)
plt.show()

# %% [markdown]
# Explore **thalach** variable
#
#
# **thalach** stands for maximum heart rate achieved

# %%
data['thalach'].nunique()
# Out:
# 91

# %% [markdown]
# Analysis of **thalach** and **target** variable

# %%
sns.distplot(data['thalach'], bins = 10)
plt.show()

# %% [markdown]
# From the above plot, We can see that the **thalach** variable is slightly negatively skewed

# %%
sns.stripplot(x = "target", y = "thalach", data = data)
plt.show()

# %% [markdown]
# From the above plot, We can see that people suffering from heart disease (target = 1) have relatively higher heart rate (**thalach**) as compared to people who are not suffering from heart disease (target = 0)

# %% [markdown]
# **3. Discovering Pattern and Relationship in Dataset**

# %% [markdown]
# Heat Map

# %%
plt.figure(figsize = (16,12))
plt.title('Correlation Heatmap from Heart Disease Dataset')
a = sns.heatmap(correlation, square = True, annot = True, fmt = '.2f', linewidths = .5)
a.set_xticklabels(a.get_xticklabels(), rotation = 90)
a.set_yticklabels(a.get_yticklabels(), rotation = 30)           
plt.show()

# %% [markdown]
# Pair Plot

# %%
var = ['age', 'trestbps', 'chol', 'thalach', 'oldpeak', 'target']
sns.pairplot(data[var], kind = 'scatter', diag_kind = 'hist')
plt.show()

# %%
plt.figure(figsize = (15, 10))
plt.scatter(x=data.age[data.target==1], y=data.thalach[(data.target==1)], c="red", s=60)
plt.scatter(x=data.age[data.target==0], y=data.thalach[(data.target==0)], s=60)
plt.legend(["Disease", "No Disease"])
plt.xlabel("Age")
plt.ylabel("Maximum Heart Rate");

# %% [markdown]
# Looks like maximum heart rate can be very predictive for the presence of a disease, regardless of age.

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# Split Data

# %%
train, test = train_test_split(data, test_size=0.2)
train, val = train_test_split(train, test_size=0.2)
print(len(train), 'train examples')
print(len(val), 'validation examples')
print(len(test), 'test examples')
# Out:
# 193 train examples
# 49 validation examples
# 61 test examples

# %% [markdown]
# Transform Pandas Dataframe into Tensorflow's Dataset

# %%
# A utility method to create a tf.data dataset from a Pandas Dataframe
def df_to_dataset(dataframe, shuffle=True, batch_size=32):
    dataframe = dataframe.copy()
    labels = dataframe.pop('target')
    ds = tf.data.Dataset.from_tensor_slices((dict(dataframe), labels))
    if shuffle:
        ds = ds.shuffle(buffer_size=len(dataframe))
    ds = ds.batch(batch_size)
    return ds

# %% [markdown]
# The data contains a mixture of categorical and numerical data
#
# Tensorflow's Feature Columns will be used

# %% [markdown]
# ![alt text](https://3.bp.blogspot.com/-3Wf_6BEn7GE/Wg4GiQ9TXDI/AAAAAAAAEGo/yoLiIyJW1c4Vh-VfP4vVjuaD92rcnVphACLcBGAs/s1600/2.jpg)

# %% [markdown]
# Source : https://www.tensorflow.org/tutorials/structured_data/feature_columns#split_the_dataframe_into_train_validation_and_test

# %%
feature_columns = []

# numeric columns
for header in ['age', 'trestbps', 'chol', 'thalach', 'oldpeak', 'slope', 'ca']:
    feature_columns.append(feature_column.numeric_column(header))

# bucketized columns
age = tf.feature_column.numeric_column("age")
age_buckets = feature_column.bucketized_column(age, boundaries=[18, 25, 30, 35, 40, 45, 50, 55, 60, 65])
feature_columns.append(age_buckets)

# indicator columns
thal = feature_column.categorical_column_with_vocabulary_list(
      'thal', ['fixed', 'normal', 'reversible'])
thal_one_hot = feature_column.indicator_column(thal)
feature_columns.append(thal_one_hot)

# embedding columns
thal_embedding = feature_column.embedding_column(thal, dimension=8)
feature_columns.append(thal_embedding)

# crossed columns
crossed_feature = feature_column.crossed_column([age_buckets, thal], hash_bucket_size=1000)
crossed_feature = feature_column.indicator_column(crossed_feature)
feature_columns.append(crossed_feature)

# %% [markdown]
# Create a feature layer

# %%
feature_layer = tf.keras.layers.DenseFeatures(feature_columns)

# %%
batch_size = 32
train_ds = df_to_dataset(train, batch_size=batch_size)
val_ds = df_to_dataset(val, shuffle=False, batch_size=batch_size)
test_ds = df_to_dataset(test, shuffle=False, batch_size=batch_size)

# %% [markdown]
# ## Model

# %% [markdown]
# Build binary classifier

# %%
model = tf.keras.Sequential([
  feature_layer,
  layers.Dense(128, activation='relu'),
  layers.Dense(128, activation='relu'),
  layers.Dense(1)
])

model.compile(optimizer='adam',
              loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
              metrics=['accuracy'])

model.fit(train_ds,
          validation_data=val_ds,
          epochs=100)
# Out:
# WARNING:tensorflow:Layer sequential is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# WARNING:tensorflow:From /Users/Haekal/opt/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/feature_column/feature_column_v2.py:4276: IndicatorColumn._variable_shape (from tensorflow.python.feature_column.feature_column_v2) is deprecated and will be removed in a future version.
# Instructions for updating:
# The old _FeatureColumn APIs are being deprecated. Please use the new FeatureColumn APIs instead.
# WARNING:tensorflow:From /Users/Haekal/opt/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/feature_column/feature_column_v2.py:4331: CrossedColumn._num_buckets (from tensorflow.python.feature_column.feature_column_v2) is deprecated and will be removed in a future version.
# Instructions for updating:
# The old _FeatureColumn APIs are being deprecated. Please use the new FeatureColumn APIs instead.
# WARNING:tensorflow:From /Users/Haekal/opt/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/feature_column/feature_column_v2.py:4331: VocabularyListCategoricalColumn._num_buckets (from tensorflow.python.feature_column.feature_column_v2) is deprecated and will be removed in a future version.
# Instructions for updating:
# The old _FeatureColumn APIs are being deprecated. Please use the new FeatureColumn APIs instead.
# Epoch 1/100
# 7/7 [==============================] - 2s 275ms/step - loss: 3.4837 - accuracy: 0.6321 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 2/100
# 7/7 [==============================] - 0s 10ms/step - loss: 1.2944 - accuracy: 0.5285 - val_loss: 0.6501 - val_accuracy: 0.7551
# Epoch 3/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.7340 - accuracy: 0.7254 - val_loss: 0.6128 - val_accuracy: 0.7551
# Epoch 4/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.7923 - accuracy: 0.6477 - val_loss: 0.4379 - val_accuracy: 0.7959
# Epoch 5/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.5090 - accuracy: 0.6995 - val_loss: 0.4295 - val_accuracy: 0.7959
# Epoch 6/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.5517 - accuracy: 0.7358 - val_loss: 0.4286 - val_accuracy: 0.7755
# Epoch 7/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.5254 - accuracy: 0.7202 - val_loss: 0.4202 - val_accuracy: 0.7755
# Epoch 8/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.5511 - accuracy: 0.7358 - val_loss: 0.6384 - val_accuracy: 0.7347
# Epoch 9/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.5987 - accuracy: 0.7254 - val_loss: 0.7510 - val_accuracy: 0.7551
# Epoch 10/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.9969 - accuracy: 0.7409 - val_loss: 0.4288 - val_accuracy: 0.7551
# Epoch 11/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.5299 - accuracy: 0.7720 - val_loss: 0.4697 - val_accuracy: 0.7551
# Epoch 12/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.7409 - accuracy: 0.7409 - val_loss: 0.4482 - val_accuracy: 0.7551
# Epoch 13/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.4754 - accuracy: 0.7927 - val_loss: 0.4548 - val_accuracy: 0.7551
# Epoch 14/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.5176 - accuracy: 0.7461 - val_loss: 0.4752 - val_accuracy: 0.7959
# Epoch 15/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.4642 - accuracy: 0.7409 - val_loss: 0.5249 - val_accuracy: 0.7551
# Epoch 16/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.4948 - accuracy: 0.7513 - val_loss: 0.4618 - val_accuracy: 0.7551
# Epoch 17/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.4868 - accuracy: 0.7565 - val_loss: 0.5684 - val_accuracy: 0.7755
# Epoch 18/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.4478 - accuracy: 0.7876 - val_loss: 0.3925 - val_accuracy: 0.8367
# Epoch 19/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.6874 - accuracy: 0.6736 - val_loss: 0.4520 - val_accuracy: 0.7551
# Epoch 20/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.5413 - accuracy: 0.7668 - val_loss: 0.5937 - val_accuracy: 0.7347
# Epoch 21/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.6128 - accuracy: 0.7617 - val_loss: 0.6043 - val_accuracy: 0.7551
# Epoch 22/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.7555 - accuracy: 0.7461 - val_loss: 0.3998 - val_accuracy: 0.8571
# Epoch 23/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.4855 - accuracy: 0.7720 - val_loss: 0.4071 - val_accuracy: 0.7551
# Epoch 24/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.4770 - accuracy: 0.7513 - val_loss: 0.3702 - val_accuracy: 0.8367
# Epoch 25/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.4525 - accuracy: 0.7513 - val_loss: 0.3914 - val_accuracy: 0.7959
# Epoch 26/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.4139 - accuracy: 0.7927 - val_loss: 0.4084 - val_accuracy: 0.7755
# Epoch 27/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.4687 - accuracy: 0.7565 - val_loss: 0.7227 - val_accuracy: 0.6939
# Epoch 28/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.6516 - accuracy: 0.7565 - val_loss: 0.7012 - val_accuracy: 0.7551
# Epoch 29/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.7821 - accuracy: 0.7565 - val_loss: 0.4542 - val_accuracy: 0.8163
# Epoch 30/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.4439 - accuracy: 0.7876 - val_loss: 0.3589 - val_accuracy: 0.8980
# Epoch 31/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.4669 - accuracy: 0.8083 - val_loss: 0.4878 - val_accuracy: 0.8367
# Epoch 32/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.5252 - accuracy: 0.7720 - val_loss: 0.5390 - val_accuracy: 0.7551
# Epoch 33/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.8471 - accuracy: 0.7409 - val_loss: 0.4338 - val_accuracy: 0.8367
# Epoch 34/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.9470 - accuracy: 0.6114 - val_loss: 0.6518 - val_accuracy: 0.7551
# Epoch 35/100
# 7/7 [==============================] - 0s 9ms/step - loss: 1.5330 - accuracy: 0.7409 - val_loss: 1.3454 - val_accuracy: 0.7551
# Epoch 36/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.9665 - accuracy: 0.7461 - val_loss: 0.8364 - val_accuracy: 0.7347
# Epoch 37/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.6811 - accuracy: 0.7150 - val_loss: 0.5124 - val_accuracy: 0.7551
# Epoch 38/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.5588 - accuracy: 0.7409 - val_loss: 0.3687 - val_accuracy: 0.7755
# Epoch 39/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.3951 - accuracy: 0.7617 - val_loss: 0.3873 - val_accuracy: 0.7959
# Epoch 40/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.3953 - accuracy: 0.7876 - val_loss: 0.3882 - val_accuracy: 0.7959
# Epoch 41/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.4044 - accuracy: 0.7461 - val_loss: 0.3830 - val_accuracy: 0.7959
# Epoch 42/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.4005 - accuracy: 0.7668 - val_loss: 0.3891 - val_accuracy: 0.7959
# Epoch 43/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.3776 - accuracy: 0.7876 - val_loss: 0.3751 - val_accuracy: 0.8163
# Epoch 44/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.3790 - accuracy: 0.8031 - val_loss: 0.3677 - val_accuracy: 0.7755
# Epoch 45/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.3823 - accuracy: 0.7668 - val_loss: 0.3594 - val_accuracy: 0.8163
# Epoch 46/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.4657 - accuracy: 0.7461 - val_loss: 0.3716 - val_accuracy: 0.8163
# Epoch 47/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.3936 - accuracy: 0.8238 - val_loss: 0.4369 - val_accuracy: 0.8163
# Epoch 48/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.4069 - accuracy: 0.8083 - val_loss: 0.4004 - val_accuracy: 0.7755
# Epoch 49/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.4094 - accuracy: 0.7513 - val_loss: 0.4005 - val_accuracy: 0.8163
# Epoch 50/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3631 - accuracy: 0.7979 - val_loss: 0.3888 - val_accuracy: 0.8163
# Epoch 51/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3810 - accuracy: 0.7720 - val_loss: 0.5143 - val_accuracy: 0.7755
# Epoch 52/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.5932 - accuracy: 0.7358 - val_loss: 0.4644 - val_accuracy: 0.7755
# Epoch 53/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.5329 - accuracy: 0.7461 - val_loss: 0.4167 - val_accuracy: 0.8367
# Epoch 54/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.4338 - accuracy: 0.8031 - val_loss: 0.4254 - val_accuracy: 0.8163
# Epoch 55/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.4734 - accuracy: 0.8135 - val_loss: 0.4211 - val_accuracy: 0.7959
# Epoch 56/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.4489 - accuracy: 0.7668 - val_loss: 0.4217 - val_accuracy: 0.7959
# Epoch 57/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.3726 - accuracy: 0.7824 - val_loss: 0.5459 - val_accuracy: 0.7347
# Epoch 58/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.4876 - accuracy: 0.8135 - val_loss: 0.4248 - val_accuracy: 0.7755
# Epoch 59/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.4653 - accuracy: 0.7409 - val_loss: 0.3947 - val_accuracy: 0.8163
# Epoch 60/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3509 - accuracy: 0.8342 - val_loss: 0.5129 - val_accuracy: 0.7755
# Epoch 61/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.4725 - accuracy: 0.8135 - val_loss: 0.4172 - val_accuracy: 0.8367
# Epoch 62/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.4273 - accuracy: 0.8394 - val_loss: 0.4203 - val_accuracy: 0.8163
# Epoch 63/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.4062 - accuracy: 0.7617 - val_loss: 0.4621 - val_accuracy: 0.7755
# Epoch 64/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.4436 - accuracy: 0.7720 - val_loss: 0.4736 - val_accuracy: 0.7755
# Epoch 65/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3808 - accuracy: 0.8187 - val_loss: 0.4325 - val_accuracy: 0.7755
# Epoch 66/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3732 - accuracy: 0.7824 - val_loss: 0.4087 - val_accuracy: 0.8163
# Epoch 67/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3490 - accuracy: 0.8031 - val_loss: 0.3932 - val_accuracy: 0.8163
# Epoch 68/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.3405 - accuracy: 0.8238 - val_loss: 0.4487 - val_accuracy: 0.7959
# Epoch 69/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.4064 - accuracy: 0.8238 - val_loss: 0.3941 - val_accuracy: 0.8163
# Epoch 70/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.3792 - accuracy: 0.7720 - val_loss: 0.4124 - val_accuracy: 0.8367
# Epoch 71/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3682 - accuracy: 0.8394 - val_loss: 0.4329 - val_accuracy: 0.7959
# Epoch 72/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.5703 - accuracy: 0.7409 - val_loss: 0.4257 - val_accuracy: 0.7959
# Epoch 73/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3413 - accuracy: 0.8601 - val_loss: 0.4428 - val_accuracy: 0.7959
# Epoch 74/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.4024 - accuracy: 0.7824 - val_loss: 0.4351 - val_accuracy: 0.8163
# Epoch 75/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3694 - accuracy: 0.8290 - val_loss: 0.4562 - val_accuracy: 0.8163
# Epoch 76/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3484 - accuracy: 0.8083 - val_loss: 0.4328 - val_accuracy: 0.7959
# Epoch 77/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.4583 - accuracy: 0.7668 - val_loss: 0.4437 - val_accuracy: 0.7959
# Epoch 78/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3547 - accuracy: 0.8290 - val_loss: 0.4189 - val_accuracy: 0.8163
# Epoch 79/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3377 - accuracy: 0.8135 - val_loss: 0.4125 - val_accuracy: 0.8163
# Epoch 80/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3377 - accuracy: 0.8446 - val_loss: 0.4099 - val_accuracy: 0.8163
# Epoch 81/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.3241 - accuracy: 0.8238 - val_loss: 0.4288 - val_accuracy: 0.7959
# Epoch 82/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.4565 - accuracy: 0.7565 - val_loss: 0.4157 - val_accuracy: 0.8163
# Epoch 83/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3400 - accuracy: 0.8394 - val_loss: 0.4142 - val_accuracy: 0.8163
# Epoch 84/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3252 - accuracy: 0.8342 - val_loss: 0.3981 - val_accuracy: 0.8163
# Epoch 85/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3328 - accuracy: 0.8342 - val_loss: 0.4300 - val_accuracy: 0.8163
# Epoch 86/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3617 - accuracy: 0.8446 - val_loss: 0.3935 - val_accuracy: 0.7959
# Epoch 87/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3633 - accuracy: 0.7772 - val_loss: 0.3923 - val_accuracy: 0.8163
# Epoch 88/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3288 - accuracy: 0.8238 - val_loss: 0.4015 - val_accuracy: 0.8163
# Epoch 89/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3244 - accuracy: 0.8497 - val_loss: 0.4061 - val_accuracy: 0.8163
# Epoch 90/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3249 - accuracy: 0.8135 - val_loss: 0.4454 - val_accuracy: 0.8163
# Epoch 91/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3422 - accuracy: 0.8601 - val_loss: 0.4261 - val_accuracy: 0.8163
# Epoch 92/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.4296 - accuracy: 0.7668 - val_loss: 0.4901 - val_accuracy: 0.7755
# Epoch 93/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.6253 - accuracy: 0.7617 - val_loss: 0.4128 - val_accuracy: 0.8163
# Epoch 94/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.5974 - accuracy: 0.7565 - val_loss: 0.3693 - val_accuracy: 0.8367
# Epoch 95/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.3689 - accuracy: 0.8394 - val_loss: 0.3983 - val_accuracy: 0.8571
# Epoch 96/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3639 - accuracy: 0.8342 - val_loss: 0.3565 - val_accuracy: 0.8367
# Epoch 97/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3463 - accuracy: 0.8187 - val_loss: 0.3833 - val_accuracy: 0.8367
# Epoch 98/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3375 - accuracy: 0.8497 - val_loss: 0.4013 - val_accuracy: 0.7959
# Epoch 99/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.6721 - accuracy: 0.7513 - val_loss: 0.4012 - val_accuracy: 0.7959
# Epoch 100/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.4004 - accuracy: 0.8394 - val_loss: 0.3884 - val_accuracy: 0.8163

# %%
loss, accuracy = model.evaluate(test_ds)
print("Accuracy", accuracy)
# Out:
# 2/2 [==============================] - 0s 4ms/step - loss: 0.3555 - accuracy: 0.8033
# Accuracy 0.8032787
